# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

#Data visualiization using Pandas*****

# %%
df=pd.read_csv('1. Weather Data.csv')
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
df.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
df.tail()
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa Weather
# 8779            9.7     100.13    Snow
# 8780            9.7     100.03    Snow
# 8781            4.8      99.95    Snow
# 8782            9.7      99.91    Snow
# 8783           11.3      99.89    Snow

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
df.fillna('Date/Time')
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
df.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %%
df.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
df['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
df.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
df['Wind Speed_km/h'].nunique()
# Out:
# 34

# %%
df.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %%
df['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
m=df[df['Wind Speed_km/h']==4].value_counts()
m
# Out:
# Date/Time        Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  Visibility_km  Press_kPa  Weather
# 1/1/2012 0:00    -1.8    -3.9              86         4                8.0            101.24     Fog              1
# 5/23/2012 4:00    12.6    9.4              81         4                24.1           100.87     Mostly Cloudy    1
# 5/5/2012 20:00    12.8   -2.0              36         4                25.0           101.62     Mainly Clear     1
# 5/5/2012 0:00     8.4     4.1              74         4                25.0           101.25     Mainly Clear     1
# 5/4/2012 18:00    17.4    13.0             75         4                24.1           100.79     Mostly Cloudy    1
#                                                                                                                  ..
# 12/26/2012 8:00  -13.7   -15.2             88         4                16.1           102.53     Mostly Cloudy    1
# ...

# %%
df['Visibility_km'].mean()
# Out:
# 27.66444672131151

# %%
df['Press_kPa'].std()
# Out:
# 0.8440047459486474

# %%
df['Rel Hum_%'].var()
# Out:
# 286.2485501984998

# %%
df[df['Weather']=='Snow'].value_counts()
# Out:
# Date/Time        Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  Visibility_km  Press_kPa  Weather
# 1/10/2012 1:00    2.3    -3.4              66         35               25.0           100.28     Snow       1
# 2/11/2012 11:00  -13.1   -18.8             62         11               24.1           101.03     Snow       1
# 2/15/2012 4:00   -0.7    -3.5              81         0                25.0           101.39     Snow       1
# 2/15/2012 21:00   1.3     0.1              92         13               8.0            101.95     Snow       1
# 2/15/2012 14:00   1.5     0.0              90         7                9.7            101.68     Snow       1
#                                                                                                            ..
# 1/6/2012 7:00    -14.4   -16.3             85         22               2.4            100.52     Snow       1
# ...

# %%
df[(df['Wind Speed_km/h']>24) & (df['Visibility_km']==25)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23      1/1/2012 23:00     5.3               2.0         79               30
# 24       1/2/2012 0:00     5.2               1.5         77               35
# 25       1/2/2012 1:00     4.6               0.0         72               39
# 26       1/2/2012 2:00     3.9              -0.9         71               32
# 27       1/2/2012 3:00     3.7              -1.5         69               33
# ...                ...     ...               ...        ...              ...
# 8705  12/28/2012 17:00    -8.6             -12.0         76               26
# 8753  12/30/2012 17:00   -12.1             -15.8         74               28
# 8755  12/30/2012 19:00   -13.4             -16.5         77               26
# 8759  12/30/2012 23:00   -12.1             -15.1         78               28
# 8760   12/31/2012 0:00   -11.1             -14.4         77               26
#
# ...

# %%
df.groupby('Weather').mean()
# Out:
#                                             Temp_C  Dew Point Temp_C  \
# Weather
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# Fog                                       4.303333          3.159333
# Freezing Drizzle                         -5.657143         -8.000000
# Freezing Drizzle,Fog                     -2.533333         -4.183333
# Freezing Drizzle,Haze                    -5.433333         -8.000000
# Freezing Drizzle,Snow                    -5.109091         -7.072727
# ...

# %%
df["Weather"]=='fog'
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
df.groupby('Weather').min()
# Out:
#                                                 Date/Time  Temp_C  \
# Weather
# Clear                                      1/11/2012 1:00   -23.3
# Cloudy                                     1/1/2012 17:00   -21.4
# Drizzle                                   1/23/2012 21:00     1.1
# Drizzle,Fog                               1/23/2012 20:00     0.0
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00     0.4
# Drizzle,Snow                             12/17/2012 15:00     0.9
# Drizzle,Snow,Fog                         12/18/2012 21:00     0.3
# Fog                                         1/1/2012 0:00   -16.0
# Freezing Drizzle                          1/13/2012 10:00    -9.0
# Freezing Drizzle,Fog                        1/1/2012 2:00    -6.4
# Freezing Drizzle,Haze                      2/1/2012 11:00    -5.8
# Freezing Drizzle,Snow                      1/13/2012 3:00    -8.3
# Freezing Fog                               1/22/2012 6:00   -19.0
# ...

# %%
df.groupby('Weather').max()
# Out:
#                                                 Date/Time  Temp_C  \
# Weather
# Clear                                       9/9/2012 5:00    32.8
# Cloudy                                     9/9/2012 23:00    30.5
# Drizzle                                    9/30/2012 3:00    18.8
# Drizzle,Fog                                9/30/2012 2:00    19.9
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00     0.4
# Drizzle,Snow                             12/19/2012 18:00     1.2
# Drizzle,Snow,Fog                          12/22/2012 3:00     1.1
# Fog                                        9/22/2012 0:00    20.8
# Freezing Drizzle                            2/1/2012 5:00    -2.3
# Freezing Drizzle,Fog                      12/10/2012 5:00    -0.3
# Freezing Drizzle,Haze                      2/1/2012 13:00    -5.0
# Freezing Drizzle,Snow                      3/2/2012 12:00    -3.3
# Freezing Fog                               3/17/2012 6:00    -0.1
# ...

# %%
df[(df['Weather']=='Clear') | (df['Visibility_km']>40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67      1/3/2012 19:00   -16.9             -24.8         50               24
# 106     1/5/2012 10:00    -6.0             -10.0         73               17
# 107     1/5/2012 11:00    -5.6             -10.2         70               22
# 108     1/5/2012 12:00    -4.7              -9.6         69               20
# 109     1/5/2012 13:00    -4.4              -9.7         66               26
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...

# %%
df[(df['Weather']=='Clear')& (df['Rel Hum_%']>50) | (df['Visibility_km']>40)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 106     1/5/2012 10:00    -6.0             -10.0         73               17
# 107     1/5/2012 11:00    -5.6             -10.2         70               22
# 108     1/5/2012 12:00    -4.7              -9.6         69               20
# 109     1/5/2012 13:00    -4.4              -9.7         66               26
# 110     1/5/2012 14:00    -5.1             -10.7         65               22
# ...                ...     ...               ...        ...              ...
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8750  12/30/2012 14:00   -11.8             -16.1         70               37
# 8751  12/30/2012 15:00   -11.3             -15.6         70               32
# 8752  12/30/2012 16:00   -11.4             -15.5         72               26
# 8756  12/30/2012 20:00   -13.8             -16.5         80               24
#
# ...

# %%
df.plot(x='Weather',y='Wind Speed_km/h',c='r')
plt.xlabel('Weather')
plt.ylabel('Wind speed')
plt.title('Weather vs Wind speed')
plt.legend()
plt.show()

# %%
sns.scatterplot(x=df['Temp_C'],y=df['Wind Speed_km/h'],color='green');
plt.show()

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.load_dataset('tips')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#VISUALIZATION USING PANDAS ONLY ****

pip install pydataset
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pydataset import data

# %%
Housing=data('Housing')
Housing
# Out:
#         price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase  \
# 1     42000.0     5850         3        1        2      yes      no      yes
# 2     38500.0     4000         2        1        1      yes      no       no
# 3     49500.0     3060         3        1        1      yes      no       no
# 4     60500.0     6650         3        1        2      yes     yes       no
# 5     61000.0     6360         2        1        1      yes      no       no
# ..        ...      ...       ...      ...      ...      ...     ...      ...
# 542   91500.0     4800         3        2        4      yes     yes       no
# 543   94000.0     6000         3        2        4      yes      no       no
# 544  103000.0     6000         3        2        4      yes     yes       no
# 545  105000.0     6000         3        2        2      yes     yes       no
# 546  105000.0     6000         3        1        2      yes      no       no
#
#     gashw airco  garagepl prefarea
# ...

# %%
Housing.plot()
# Out:
# <AxesSubplot:>

# %%
Housing.plot(y='price');

# %%
import matplotlib.pyplot as plt
Housing.plot(y=['price','lotsize','bathrms'],
            title='House Prices',
            xlabel='House Index',
            ylabel='Pricing',
             sharey=True,
             subplots=True,
             layout=(1,3),
            );
plt.tight_layout()

# %%
nile=data('Nile')
nile
# Out:
#      time  Nile
# 1    1871  1120
# 2    1872  1160
# 3    1873   963
# 4    1874  1210
# 5    1875  1160
# 6    1876  1160
# 7    1877   813
# 8    1878  1230
# 9    1879  1370
# 10   1880  1140
# 11   1881   995
# 12   1882   935
# 13   1883  1110
# 14   1884   994
# 15   1885  1020
# 16   1886   960
# 17   1887  1180
# 18   1888   799
# 19   1889   958
# 20   1890  1140
# 21   1891  1100
# 22   1892  1210
# 23   1893  1150
# 24   1894  1250
# 25   1895  1260
# 26   1896  1220
# 27   1897  1030
# 28   1898  1100
# 29   1899   774
# 30   1900   840
# 31   1901   874
# 32   1902   694
# 33   1903   940
# 34   1904   833
# 35   1905   701
# 36   1906   916
# 37   1907   692
# 38   1908  1020
# 39   1909  1050
# 40   1910   969
# 41   1911   831
# 42   1912   726
# 43   1913   456
# 44   1914   824
# 45   1915   702
# 46   1916  1120
# 47   1917  1100
# 48   1918   832
# 49   1919   764
# 50   1920   821
# 51   1921   768
# 52   1922   845
# 53   1923   864
# 54   1924   862
# ...

# %%
nile.head()
# Out:
#    time  Nile
# 1  1871  1120
# 2  1872  1160
# 3  1873   963
# 4  1874  1210
# 5  1875  1160

# %%
nile.plot();

# %%
#line plot
nile.plot(x='time',
         y='Nile',
         xlabel='Year',
         ylabel='Nile river',
         title='Year vs Nile river',
         figsize=(20,10),
         legend=False);

# %%
h=data('Housing')
h
# Out:
#         price  lotsize  bedrooms  bathrms  stories driveway recroom fullbase  \
# 1     42000.0     5850         3        1        2      yes      no      yes
# 2     38500.0     4000         2        1        1      yes      no       no
# 3     49500.0     3060         3        1        1      yes      no       no
# 4     60500.0     6650         3        1        2      yes     yes       no
# 5     61000.0     6360         2        1        1      yes      no       no
# ..        ...      ...       ...      ...      ...      ...     ...      ...
# 542   91500.0     4800         3        2        4      yes     yes       no
# 543   94000.0     6000         3        2        4      yes      no       no
# 544  103000.0     6000         3        2        4      yes     yes       no
# 545  105000.0     6000         3        2        2      yes     yes       no
# 546  105000.0     6000         3        1        2      yes      no       no
#
#     gashw airco  garagepl prefarea
# ...

# %%
bedrooms_count=h.groupby('bedrooms')['bedrooms'].count()

# %%
bedrooms_count.plot()
# Out:
# <AxesSubplot:xlabel='bedrooms'>

# %%
#bar plot
bedrooms_count.plot(kind='bar',
                   ylabel='count',
                   xlabel='bedrooms count',
                   title='count vs bedrooms',
                   figsize=(10,6));

# %%
#Box plot
h.plot(kind='box');

# %%
h.plot(kind='box',
      y='garagepl');

# %%
h.plot(kind='box',
      y=['price','lotsize'],
     );

# %%
h.boxplot(column='price',
        by='bedrooms' ,
         grid=False);

# %%
# Histogram plot (*****specify no of bins*****)
h.plot(kind='hist',
      bins=15);

# %%
h.plot(kind='hist',
      y='price',
      bins=15,
      legend=False);

# %%
#kde plot (gives a smooth curve and this ********doesnt have bins only histogram plot has bins********)
h.plot(kind='kde',
      y='price',
       xlim=(0,50000),
      legend=False);

# %%
#scatter plot (Here need to specify both x and y cause we are tracing the rln btw both in other plots no need to specify both x and y values)

# %%
#scatter plot(Put the response on Y-axis and predictor on X-axis) EX----(Icecrm shares(Y-axis) vs Rising temp(X-axis))
h.plot(kind='scatter',
      x='lotsize',
      y='price');

# %%
# pie chart (always not clear better prefer bar plot for clearer visualization)

s=h['stories'].value_counts()
s
# Out:
# 2    238
# 1    227
# 4     41
# 3     40
# Name: stories, dtype: int64

# %%
s.plot(kind='pie',
      title="stories count");

# %%
housing_df=data('Housing')

# %%
#matlplotlib BOX plot*********

plt.boxplot(housing_df['price'], 
            notch=True, 
            vert=False, 
            showmeans=True, 
            whis=2.5)
plt.title('House prices')
plt.ylabel('Overall')
plt.yticks([]);
